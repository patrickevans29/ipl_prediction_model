# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

# %%
# Download the dataset to a dataframe
complete_df = pd.read_csv('../raw_data/complete_cleaned_dataset.csv')
complete_df.head(1)
# Out:
#    Unnamed: 0       ID  innings  overs  ballnumber       batter  \
# 0           0  1312200        1      1           1  ybk jaiswal
#
#            bowler non_striker extra_type  batsman_run  ...  TossDecision  \
# 0  mohammed shami  jc buttler    noextra            0  ...           bat
#
#    SuperOver     WinningTeam    WonBy Margin Player_of_Match  \
# 0          n  gujarat titans  wickets    7.0       hh pandya
#
#                                         Team1Players  \
# 0  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...  cb gaffaney  nitin menon
#
# [1 rows x 36 columns]

# %%
# Check the columns
complete_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'innings', 'overs', 'ballnumber', 'batter',
#        'bowler', 'non_striker', 'extra_type', 'batsman_run', 'extras_run',
#        'total_run', 'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'City', 'Date', 'Season',
#        'MatchNumber', 'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision',
#        'SuperOver', 'WinningTeam', 'WonBy', 'Margin', 'Player_of_Match',
#        'Team1Players', 'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# Create 'innings_total' feature

complete_df['innings_total'] = complete_df.groupby(['ID', 'innings'])['total_run'].transform('sum')
complete_df.Season
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#           ...
# 225949    2008
# 225950    2008
# 225951    2008
# 225952    2008
# 225953    2008
# Name: Season, Length: 225954, dtype: int64

# %%
# Remove unnecessary features

to_model_df = complete_df[['ID', 'innings', 'batter',
       'bowler', 'batsman_run', 'extras_run',
       'total_run', 'BattingTeam', 'City', 'Date', 'Season',
       'MatchNumber', 'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision',
       'SuperOver', 'WinningTeam', 'WonBy', 'Margin', 'Player_of_Match',
       'Team1Players', 'Team2Players', 'innings_total']].copy()

# %%
# Engineer the team_batting_average feature

to_model_df['team_batting_average'] = to_model_df.groupby('BattingTeam')['total_run'].transform('sum') / to_model_df.groupby('BattingTeam')['ID'].transform('nunique')

# %%
# Drop any rows where innings is not == 1 or 2

to_model_df.innings.value_counts()
# Out:
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: innings, dtype: int64

# %%
to_model_df = to_model_df[(to_model_df['innings'] == 1) | (to_model_df['innings'] == 2)]

# %%
# Convert the innings totals into columns

# Group by 'ID' and 'innings' and calculate innings_total
innings_totals = to_model_df.groupby(['ID', 'innings'])['innings_total'].mean().unstack()
innings_totals.columns = ['TeamA_innings_total', 'TeamB_innings_total']

# Merge the innings_totals DataFrame back into new_df on 'ID'
to_model_df = pd.merge(to_model_df, innings_totals, left_on='ID', right_index=True)

# %%
# Convert the average innings totals into columns

# Group by 'ID' and 'innings' and calculate average innings_total
batting_averages = to_model_df.groupby(['ID', 'innings'])['team_batting_average'].mean().unstack()
batting_averages.columns = ['TeamA_batting_average', 'TeamB_batting_average']

# Merge the innings_totals DataFrame back into new_df on 'ID'
to_model_df = pd.merge(to_model_df, batting_averages, left_on='ID', right_index=True)

# %%
to_model_df.head(50)
# Out:
#          ID  innings       batter          bowler  batsman_run  extras_run  \
# 0   1312200        1  ybk jaiswal  mohammed shami            0           0
# 1   1312200        1  ybk jaiswal  mohammed shami            0           1
# 2   1312200        1   jc buttler  mohammed shami            1           0
# 3   1312200        1  ybk jaiswal  mohammed shami            0           0
# 4   1312200        1  ybk jaiswal  mohammed shami            0           0
# 5   1312200        1  ybk jaiswal  mohammed shami            0           0
# 6   1312200        1   jc buttler      yash dayal            0           0
# 7   1312200        1   jc buttler      yash dayal            0           0
# 8   1312200        1   jc buttler      yash dayal            4           0
# 9   1312200        1   jc buttler      yash dayal            0           0
# 10  1312200        1   jc buttler      yash dayal            1           0
# 11  1312200        1  ybk jaiswal      yash dayal            0           0
# 12  1312200        1   jc buttler  mohammed shami            1           0
# 13  1312200        1  ybk jaiswal  mohammed shami            0           0
# 14  1312200        1  ybk jaiswal  mohammed shami            4           0
# 15  1312200        1  ybk jaiswal  mohammed shami            0           0
# 16  1312200        1  ybk jaiswal  mohammed shami            6           0
# 17  1312200        1  ybk jaiswal  mohammed shami            3           0
# 18  1312200        1  ybk jaiswal      yash dayal            1           0
# 19  1312200        1   jc buttler      yash dayal            1           0
# 20  1312200        1  ybk jaiswal      yash dayal            0           0
# 21  1312200        1  ybk jaiswal      yash dayal            2           0
# 22  1312200        1  ybk jaiswal      yash dayal            6           0
# 23  1312200        1  ybk jaiswal      yash dayal            0           0
# 24  1312200        1   jc buttler     lh ferguson            0           0
# 25  1312200        1   jc buttler     lh ferguson            1           0
# 26  1312200        1    sv samson     lh ferguson            4           0
# 27  1312200        1    sv samson     lh ferguson            1           0
# 28  1312200        1   jc buttler     lh ferguson            0           0
# 29  1312200        1   jc buttler     lh ferguson            0           0
# 30  1312200        1    sv samson     rashid khan            4           0
# 31  1312200        1    sv samson     rashid khan            1           0
# 32  1312200        1   jc buttler     rashid khan            1           0
# 33  1312200        1    sv samson     rashid khan            0           0
# 34  1312200        1    sv samson     rashid khan            1           0
# 35  1312200        1   jc buttler     rashid khan            0           0
# 36  1312200        1    sv samson     lh ferguson            0           0
# 37  1312200        1    sv samson     lh ferguson            1           0
# 38  1312200        1   jc buttler     lh ferguson            0           0
# 39  1312200        1   jc buttler     lh ferguson            4           0
# 40  1312200        1   jc buttler     lh ferguson            4           0
# 41  1312200        1   jc buttler     lh ferguson            1           0
# 42  1312200        1   jc buttler     rashid khan            1           0
# 43  1312200        1    sv samson     rashid khan            1           0
# 44  1312200        1   jc buttler     rashid khan            0           0
# 45  1312200        1   jc buttler     rashid khan            1           0
# 46  1312200        1    sv samson     rashid khan            1           0
# 47  1312200        1   jc buttler     rashid khan            1           0
# 48  1312200        1   jc buttler       hh pandya            1           0
# 49  1312200        1    sv samson       hh pandya            0           0
#
#     total_run       BattingTeam       City        Date  ...  Margin  \
# 0           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 1           1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 2           1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 3           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 4           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 5           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 6           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 7           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 8           4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 9           0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 10          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 11          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 12          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 13          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 14          4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 15          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 16          6  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 17          3  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 18          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 19          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 20          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 21          2  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 22          6  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 23          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 24          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 25          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 26          4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 27          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 28          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 29          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 30          4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 31          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 32          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 33          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 34          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 35          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 36          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 37          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 38          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 39          4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 40          4  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 41          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 42          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 43          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 44          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 45          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 46          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 47          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 48          1  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
# 49          0  rajasthan royals  ahmedabad  2022-05-29  ...     7.0
#
#    Player_of_Match                                       Team1Players  \
# 0        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 1        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 2        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 3        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 4        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 5        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 6        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 7        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 8        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 9        hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 10       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 11       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 12       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 13       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 14       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 15       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 16       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 17       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 18       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 19       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 20       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 21       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 22       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 23       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 24       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 25       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 26       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 27       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 28       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 29       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 30       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 31       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 32       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 33       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 34       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 35       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 36       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 37       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 38       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 39       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 40       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 41       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 42       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 43       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 44       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 45       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 46       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 47       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 48       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 49       hh pandya  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
#
#                                          Team2Players innings_total  \
# 0   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 1   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 2   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 3   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 4   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 5   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 6   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 7   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 8   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 9   ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 10  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 11  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 12  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 13  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 14  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 15  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 16  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 17  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 18  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 19  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 20  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 21  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 22  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 23  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 24  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 25  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 26  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 27  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 28  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 29  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 30  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 31  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 32  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 33  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 34  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 35  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 36  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 37  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 38  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 39  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 40  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 41  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 42  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 43  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 44  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 45  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 46  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 47  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 48  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 49  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
#
#    team_batting_average TeamA_innings_total TeamB_innings_total  \
# 0            155.397906               130.0               133.0
# 1            155.397906               130.0               133.0
# 2            155.397906               130.0               133.0
# 3            155.397906               130.0               133.0
# 4            155.397906               130.0               133.0
# 5            155.397906               130.0               133.0
# 6            155.397906               130.0               133.0
# 7            155.397906               130.0               133.0
# 8            155.397906               130.0               133.0
# 9            155.397906               130.0               133.0
# 10           155.397906               130.0               133.0
# 11           155.397906               130.0               133.0
# 12           155.397906               130.0               133.0
# 13           155.397906               130.0               133.0
# 14           155.397906               130.0               133.0
# 15           155.397906               130.0               133.0
# 16           155.397906               130.0               133.0
# 17           155.397906               130.0               133.0
# 18           155.397906               130.0               133.0
# 19           155.397906               130.0               133.0
# 20           155.397906               130.0               133.0
# 21           155.397906               130.0               133.0
# 22           155.397906               130.0               133.0
# 23           155.397906               130.0               133.0
# 24           155.397906               130.0               133.0
# 25           155.397906               130.0               133.0
# 26           155.397906               130.0               133.0
# 27           155.397906               130.0               133.0
# 28           155.397906               130.0               133.0
# 29           155.397906               130.0               133.0
# 30           155.397906               130.0               133.0
# 31           155.397906               130.0               133.0
# 32           155.397906               130.0               133.0
# 33           155.397906               130.0               133.0
# 34           155.397906               130.0               133.0
# 35           155.397906               130.0               133.0
# 36           155.397906               130.0               133.0
# 37           155.397906               130.0               133.0
# 38           155.397906               130.0               133.0
# 39           155.397906               130.0               133.0
# 40           155.397906               130.0               133.0
# 41           155.397906               130.0               133.0
# 42           155.397906               130.0               133.0
# 43           155.397906               130.0               133.0
# 44           155.397906               130.0               133.0
# 45           155.397906               130.0               133.0
# 46           155.397906               130.0               133.0
# 47           155.397906               130.0               133.0
# 48           155.397906               130.0               133.0
# 49           155.397906               130.0               133.0
#
#    TeamA_batting_average TeamB_batting_average
# 0             155.397906              166.4375
# 1             155.397906              166.4375
# 2             155.397906              166.4375
# 3             155.397906              166.4375
# 4             155.397906              166.4375
# 5             155.397906              166.4375
# 6             155.397906              166.4375
# 7             155.397906              166.4375
# 8             155.397906              166.4375
# 9             155.397906              166.4375
# 10            155.397906              166.4375
# 11            155.397906              166.4375
# 12            155.397906              166.4375
# 13            155.397906              166.4375
# 14            155.397906              166.4375
# 15            155.397906              166.4375
# 16            155.397906              166.4375
# 17            155.397906              166.4375
# 18            155.397906              166.4375
# 19            155.397906              166.4375
# 20            155.397906              166.4375
# 21            155.397906              166.4375
# 22            155.397906              166.4375
# 23            155.397906              166.4375
# 24            155.397906              166.4375
# 25            155.397906              166.4375
# 26            155.397906              166.4375
# 27            155.397906              166.4375
# 28            155.397906              166.4375
# 29            155.397906              166.4375
# 30            155.397906              166.4375
# 31            155.397906              166.4375
# 32            155.397906              166.4375
# 33            155.397906              166.4375
# 34            155.397906              166.4375
# 35            155.397906              166.4375
# 36            155.397906              166.4375
# 37            155.397906              166.4375
# 38            155.397906              166.4375
# 39            155.397906              166.4375
# 40            155.397906              166.4375
# 41            155.397906              166.4375
# 42            155.397906              166.4375
# 43            155.397906              166.4375
# 44            155.397906              166.4375
# 45            155.397906              166.4375
# 46            155.397906              166.4375
# 47            155.397906              166.4375
# 48            155.397906              166.4375
# 49            155.397906              166.4375
#
# [50 rows x 30 columns]

# %%
# Drop ID duplicates now that the data has been generated

to_model_df = to_model_df.drop_duplicates(subset=['ID'])
to_model_df
# Out:
#              ID  innings        batter          bowler  batsman_run  \
# 0       1312200        1   ybk jaiswal  mohammed shami            0
# 233     1312199        1       v kohli        ta boult            0
# 469     1312198        1       v kohli     mohsin khan            0
# 725     1312197        1   ybk jaiswal  mohammed shami            0
# 977     1304116        1       pk garg  ls livingstone            1
# ...         ...      ...           ...             ...          ...
# 224776   335986        1  ac gilchrist        ab dinda            1
# 225016   335985        1      l ronchi         p kumar            0
# 225262   335984        1       t kohli      gd mcgrath            0
# 225481   335983        1      pa patel           b lee            0
# 225729   335982        1    sc ganguly         p kumar            0
#
#         extras_run  total_run                  BattingTeam        City  \
# 0                0          0             rajasthan royals   ahmedabad
# 233              0          0  royal challengers bangalore   ahmedabad
# 469              0          0  royal challengers bangalore     kolkata
# 725              0          0             rajasthan royals     kolkata
# 977              0          1          sunrisers hyderabad      mumbai
# ...            ...        ...                          ...         ...
# 224776           0          1              deccan chargers     kolkata
# 225016           0          0               mumbai indians      mumbai
# 225262           0          0             rajasthan royals       delhi
# 225481           0          0          chennai super kings  chandigarh
# 225729           1          1        kolkata knight riders   bangalore
#
#               Date  ...  Margin Player_of_Match  \
# 0       2022-05-29  ...     7.0       hh pandya
# 233     2022-05-27  ...     7.0      jc buttler
# 469     2022-05-25  ...    14.0      rm patidar
# 725     2022-05-24  ...     7.0       da miller
# 977     2022-05-22  ...     5.0   harpreet brar
# ...            ...  ...     ...             ...
# 224776  2008-04-20  ...     5.0       dj hussey
# 225016  2008-04-20  ...     5.0      mv boucher
# 225262  2008-04-19  ...     9.0     mf maharoof
# 225481  2008-04-19  ...    33.0      mek hussey
# 225729  2008-04-18  ...   140.0     bb mccullum
#
#                                              Team1Players  \
# 0       ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 233     ['v kohli', 'f du plessis', 'rm patidar', 'gj ...
# 469     ['v kohli', 'f du plessis', 'rm patidar', 'gj ...
# 725     ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 977     ['pk garg', 'abhishek sharma', 'ra tripathi', ...
# ...                                                   ...
# 224776  ['wp saha', 'bb mccullum', 'rt ponting', 'sc g...
# 225016  ['l ronchi', 'st jayasuriya', 'dj thornely', '...
# 225262  ['g gambhir', 'v sehwag', 's dhawan', 'mk tiwa...
# 225481  ['k goel', 'jr hopes', 'kc sangakkara', 'yuvra...
# 225729  ['r dravid', 'w jaffer', 'v kohli', 'jh kallis...
#
#                                              Team2Players innings_total  \
# 0       ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 233     ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...           157
# 469     ['q de kock', 'kl rahul', 'm vohra', 'dj hooda...           207
# 725     ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           188
# 977     ['jm bairstow', 's dhawan', 'm shahrukh khan',...           157
# ...                                                   ...           ...
# 224776  ['ac gilchrist', 'y venugopal rao', 'vvs laxma...           110
# 225016  ['s chanderpaul', 'r dravid', 'lrpl taylor', '...           165
# 225262  ['t kohli', 'yk pathan', 'sr watson', 'm kaif'...           129
# 225481  ['pa patel', 'ml hayden', 'mek hussey', 'ms dh...           240
# 225729  ['sc ganguly', 'bb mccullum', 'rt ponting', 'd...           222
#
#        team_batting_average TeamA_innings_total TeamB_innings_total  \
# 0                155.397906               130.0               133.0
# 233              155.707965               157.0               161.0
# 469              155.707965               207.0               193.0
# 725              155.397906               188.0               191.0
# 977              155.546053               157.0               160.0
# ...                     ...                 ...                 ...
# 224776           152.840000               110.0               112.0
# 225016           158.714286               165.0               166.0
# 225262           155.397906               129.0               132.0
# 225481           160.543269               240.0               207.0
# 225729           153.367713               222.0                82.0
#
#        TeamA_batting_average TeamB_batting_average
# 0                 155.397906            166.437500
# 233               155.707965            155.397906
# 469               155.707965            169.866667
# 725               155.397906            166.437500
# 977               155.546053            158.518349
# ...                      ...                   ...
# 224776            152.840000            153.367713
# 225016            158.714286            155.707965
# 225262            155.397906            153.754464
# 225481            160.543269            158.518349
# 225729            153.367713            155.707965
#
# [950 rows x 30 columns]

# %%
to_model_df.columns
# Out:
# Index(['ID', 'innings', 'batter', 'bowler', 'batsman_run', 'extras_run',
#        'total_run', 'BattingTeam', 'City', 'Date', 'Season', 'MatchNumber',
#        'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision', 'SuperOver',
#        'WinningTeam', 'WonBy', 'Margin', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'innings_total', 'team_batting_average',
#        'TeamA_innings_total', 'TeamB_innings_total', 'TeamA_batting_average',
#        'TeamB_batting_average'],
#       dtype='object')

# %%
checker_df = to_model_df[['ID', 'Team1', 'Team2', 'TossWinner', 'TossDecision', 'TeamA_innings_total', 'TeamB_innings_total', 'WinningTeam']]
checker_df.head(20)
# Out:
#            ID                        Team1                        Team2  \
# 0     1312200             rajasthan royals               gujarat titans
# 233   1312199  royal challengers bangalore             rajasthan royals
# 469   1312198  royal challengers bangalore         lucknow super giants
# 725   1312197             rajasthan royals               gujarat titans
# 977   1304116          sunrisers hyderabad                 punjab kings
# 1197  1304115               delhi capitals               mumbai indians
# 1444  1304114          chennai super kings             rajasthan royals
# 1691  1304113               gujarat titans  royal challengers bangalore
# 1928  1304112         lucknow super giants        kolkata knight riders
# 2177  1304111          sunrisers hyderabad               mumbai indians
# 2432  1304110               delhi capitals                 punjab kings
# 2681  1304109             rajasthan royals         lucknow super giants
# 2932  1304108          chennai super kings               gujarat titans
# 3176  1304107        kolkata knight riders          sunrisers hyderabad
# 3427  1304106                 punjab kings  royal challengers bangalore
# 3679  1304105          chennai super kings               mumbai indians
# 3877  1304104             rajasthan royals               delhi capitals
# 4116  1304103               gujarat titans         lucknow super giants
# 4328  1304102        kolkata knight riders               mumbai indians
# 4561  1304101          chennai super kings               delhi capitals
#
#                        TossWinner TossDecision  TeamA_innings_total  \
# 0                rajasthan royals          bat                130.0
# 233              rajasthan royals        field                157.0
# 469          lucknow super giants        field                207.0
# 725                gujarat titans        field                188.0
# 977           sunrisers hyderabad          bat                157.0
# 1197               mumbai indians        field                159.0
# 1444          chennai super kings          bat                150.0
# 1691               gujarat titans          bat                168.0
# 1928         lucknow super giants          bat                210.0
# 2177               mumbai indians        field                193.0
# 2432                 punjab kings        field                159.0
# 2681             rajasthan royals          bat                178.0
# 2932          chennai super kings          bat                133.0
# 3176        kolkata knight riders          bat                177.0
# 3427  royal challengers bangalore        field                209.0
# 3679               mumbai indians        field                 97.0
# 3877               delhi capitals        field                160.0
# 4116               gujarat titans          bat                144.0
# 4328               mumbai indians        field                165.0
# 4561               delhi capitals        field                208.0
#
#       TeamB_innings_total                  WinningTeam
# 0                   133.0               gujarat titans
# 233                 161.0             rajasthan royals
# 469                 193.0  royal challengers bangalore
# 725                 191.0               gujarat titans
# 977                 160.0                 punjab kings
# 1197                160.0               mumbai indians
# 1444                151.0             rajasthan royals
# 1691                170.0  royal challengers bangalore
# 1928                208.0         lucknow super giants
# 2177                190.0          sunrisers hyderabad
# 2432                142.0               delhi capitals
# 2681                154.0             rajasthan royals
# 2932                137.0               gujarat titans
# 3176                123.0        kolkata knight riders
# 3427                155.0                 punjab kings
# 3679                103.0               mumbai indians
# 3877                161.0               delhi capitals
# 4116                 82.0               gujarat titans
# 4328                113.0        kolkata knight riders
# 4561                117.0          chennai super kings

# %%
to_model_df.head()
# Out:
#           ID  innings       batter          bowler  batsman_run  extras_run  \
# 0    1312200        1  ybk jaiswal  mohammed shami            0           0
# 233  1312199        1      v kohli        ta boult            0           0
# 469  1312198        1      v kohli     mohsin khan            0           0
# 725  1312197        1  ybk jaiswal  mohammed shami            0           0
# 977  1304116        1      pk garg  ls livingstone            1           0
#
#      total_run                  BattingTeam       City        Date  ...  \
# 0            0             rajasthan royals  ahmedabad  2022-05-29  ...
# 233          0  royal challengers bangalore  ahmedabad  2022-05-27  ...
# 469          0  royal challengers bangalore    kolkata  2022-05-25  ...
# 725          0             rajasthan royals    kolkata  2022-05-24  ...
# 977          1          sunrisers hyderabad     mumbai  2022-05-22  ...
#
#      Margin Player_of_Match  \
# 0       7.0       hh pandya
# 233     7.0      jc buttler
# 469    14.0      rm patidar
# 725     7.0       da miller
# 977     5.0   harpreet brar
#
#                                           Team1Players  \
# 0    ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 233  ['v kohli', 'f du plessis', 'rm patidar', 'gj ...
# 469  ['v kohli', 'f du plessis', 'rm patidar', 'gj ...
# 725  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...
# 977  ['pk garg', 'abhishek sharma', 'ra tripathi', ...
#
#                                           Team2Players innings_total  \
# 0    ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           130
# 233  ['ybk jaiswal', 'jc buttler', 'sv samson', 'd ...           157
# 469  ['q de kock', 'kl rahul', 'm vohra', 'dj hooda...           207
# 725  ['wp saha', 'shubman gill', 'ms wade', 'hh pan...           188
# 977  ['jm bairstow', 's dhawan', 'm shahrukh khan',...           157
#
#     team_batting_average TeamA_innings_total TeamB_innings_total  \
# 0             155.397906               130.0               133.0
# 233           155.707965               157.0               161.0
# 469           155.707965               207.0               193.0
# 725           155.397906               188.0               191.0
# 977           155.546053               157.0               160.0
#
#     TeamA_batting_average TeamB_batting_average
# 0              155.397906            166.437500
# 233            155.707965            155.397906
# 469            155.707965            169.866667
# 725            155.397906            166.437500
# 977            155.546053            158.518349
#
# [5 rows x 30 columns]

# %%
to_model_df.columns
# Out:
# Index(['ID', 'innings', 'batter', 'bowler', 'batsman_run', 'extras_run',
#        'total_run', 'BattingTeam', 'City', 'Date', 'Season', 'MatchNumber',
#        'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision', 'SuperOver',
#        'WinningTeam', 'WonBy', 'Margin', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'innings_total', 'team_batting_average',
#        'TeamA_innings_total', 'TeamB_innings_total', 'TeamA_batting_average',
#        'TeamB_batting_average'],
#       dtype='object')

# %%
final_to_model_df = to_model_df[['ID', 'City', 'Date', 'Season', 'MatchNumber',
       'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision',
       'WinningTeam', 'innings_total', 'TeamA_batting_average',
       'TeamB_batting_average',
       'TeamA_innings_total', 'TeamB_innings_total']].copy()

# %%
final_to_model_df.to_csv("../raw_data/final_to_model_df.csv", index=False)

# %%
final_to_model_df.head()
# Out:
#           ID       City        Date  Season  MatchNumber  \
# 0    1312200  ahmedabad  2022-05-29    2022        final
# 233  1312199  ahmedabad  2022-05-27    2022  qualifier 2
# 469  1312198    kolkata  2022-05-25    2022   eliminator
# 725  1312197    kolkata  2022-05-24    2022  qualifier 1
# 977  1304116     mumbai  2022-05-22    2022           70
#
#                            Team1                 Team2  \
# 0               rajasthan royals        gujarat titans
# 233  royal challengers bangalore      rajasthan royals
# 469  royal challengers bangalore  lucknow super giants
# 725             rajasthan royals        gujarat titans
# 977          sunrisers hyderabad          punjab kings
#
#                                 Venue            TossWinner TossDecision  \
# 0    narendra modi stadium, ahmedabad      rajasthan royals          bat
# 233  narendra modi stadium, ahmedabad      rajasthan royals        field
# 469                      eden gardens  lucknow super giants        field
# 725                      eden gardens        gujarat titans        field
# 977                  wankhede stadium   sunrisers hyderabad          bat
#
#                      WinningTeam  innings_total  TeamA_batting_average  \
# 0                 gujarat titans            130             155.397906
# 233             rajasthan royals            157             155.707965
# 469  royal challengers bangalore            207             155.707965
# 725               gujarat titans            188             155.397906
# 977                 punjab kings            157             155.546053
#
#      TeamB_batting_average  TeamA_innings_total  TeamB_innings_total
# 0               166.437500                130.0                133.0
# 233             155.397906                157.0                161.0
# 469             169.866667                207.0                193.0
# 725             166.437500                188.0                191.0
# 977             158.518349                157.0                160.0
